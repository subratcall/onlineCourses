# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd
import matplotlib.pyplot as plt

# %%
milk_production = pd.read_csv('datasets/milk_production.csv', parse_dates=True, index_col='date')

# %%
milk_production.head()
# Out:
#             pounds_per_cow
# date
# 1962-01-01           589.0
# 1962-02-01           561.0
# 1962-03-01           640.0
# 1962-04-01           656.0
# 1962-05-01           727.0

# %%
decomp = seasonal_decompose(milk_production, period=12)
decomp.plot()
plt.show()

# %%
set.seed(2016)

# %%
test_1_scores = round(rnorm(50, 78, 10))

# %%
print(test_1_scores)
# Out:
#  [1] 76 69 53 67 80 62 94 66 75 74 85 85 73 72 83 92 75 67 74 86 88 81 59 78 78
# [26] 86 80 87 78 74 83 83 83 70 63 98 72 85 75 80 91 84 66 85 74 72 80 75 55 90

# %%
test_2_scores = round(rnorm(50, 78,14))

# %%
plot(test_2_scores~test_1_scores)
# Out:
# plot without title
